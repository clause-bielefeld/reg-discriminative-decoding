# %%
import os
from glob import glob
import json
from nltk import word_tokenize, ngrams
import pandas as pd
import pickle
from itertools import chain

# %%
class Vocabulary(object):
    """Simple vocabulary wrapper."""
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0
        self.unknown_token = '<unk>'

    def add_word(self, word):
        if not word in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1

    def __call__(self, word):
        if not word in self.word2idx:
            return self.word2idx[self.unknown_token]
        return self.word2idx[word]

    def __len__(self):
        return len(self.word2idx)
    

# from Van Miltenburg et al. 2018: Measuring the Diversity of Automatic Image Descriptions
# https://github.com/evanmiltenburg/MeasureDiversity


def chunks(l, n):
    """
    Yield successive n-sized chunks from l.
    
    From: https://stackoverflow.com/a/312464/2899924
    """
    for i in range(0, len(l), n):
        yield l[i:i + n]

def type_token_ratio(sentences, n=1000):
    """
    Compute average type-token ratio (normalized over n tokens)
    with a repeated sample of n words.
    """
    all_words = [word for sentence in sentences for word in sentence]
    ttrs = []
    if len(all_words) < n:
        print("Warning: not enough tokens!")
        return None
    for chunk in chunks(all_words, n):
        if len(chunk) == n:
            types = set(chunk)
            ttr = float(len(types))/n
            ttrs.append(ttr)
    final_ttr = float(sum(ttrs))/len(ttrs)
    return final_ttr


def ngram_ttr(sentences, n=2, window_size=1000):
    """
    Compute average ngram type-token ratio (normalized over window_size ngrams)
    with a repeated sample of n words.
    """
    all_ngrams = list(ngrams([word for sentence in sentences for word in sentence], n))
    ttrs = []
    for chunk in chunks(all_ngrams, window_size):
        if len(chunk) == window_size:
            types = set(chunk)
            ttr = float(len(types))/window_size
            ttrs.append(ttr)
    final_ttr = float(sum(ttrs))/len(ttrs)
    return final_ttr


def bigram_ttr(sentences):
    "Compute bigram TTR"
    return ngram_ttr(sentences, n=2)


def trigram_ttr(sentences):
    "Compute trigram TTR"
    return ngram_ttr(sentences, n=3)

def coverage(system_types, train_types):  # adopted to our setting
    """
    Compute coverage for a specific system.
    
    This function is agnostic to whether you want coverage over entire Val or only
    the set of learnable types.
    """
    recalled = system_types & train_types
    return {"recalled": recalled,
            "score": len(recalled)/len(train_types),
            "not_in_val": train_types - system_types}

# %%
def compute_scores(dset, split, input_dir, vocab_dir):
    
    setting = f'{split}{dset.replace("refcoco", "")}'
    print(setting)
       
    input_path = os.path.join(input_dir, f'{dset.replace("+", "plus")}/filtered')
    vocab_path = os.path.join(vocab_dir, f'{dset.replace("+","plus")}_vocab.pkl')
    files = glob(f'{input_path}/{dset}_{split}**')
                
    with open(vocab_path, 'rb') as f:
        vocab = pickle.load(f)
        model_vocab = {word for word in vocab.word2idx.keys() if word not in ['<pad>', '<start>', '<end>', '<unk>']}

    res = []

    for file in sorted(files):

        system = os.path.split(file)[-1].replace('_cleaned_filtered.json', ''
            ).replace(f'{dset}_', ''
            ).replace(f'{split}_', '')
        
        with open(file) as f:
            system_refexps = [word_tokenize(x['caption']) for x in json.load(f)]

        ttr1 = type_token_ratio(system_refexps)
        ttr2 = bigram_ttr(system_refexps)
        #ttr3 = trigram_ttr(system_refexps)

        system_types = set(chain(*system_refexps))
        system_coverage = coverage(system_types, model_vocab)
        
        res.append({
            'system': system,
            'TTR1': ttr1,
            'TTR2': ttr2,
            #'TTR3': ttr3,
            'cov.': system_coverage['score']
        })

    df = pd.DataFrame(res)
    ordering = ['greedy_l-na_r-na', 'beam_l-na_r-na', 'predfuse_es_l-0-7_r-na','predfuse_es_l-0-5_r-na','predfuse_es_l-0-3_r-na','rsa_l-na_r-0-5','rsa_l-na_r-1-0','rsa_l-na_r-5-0','annsample']
    df['system'] = pd.Categorical(df['system'], categories=ordering)
    df = df.set_index('system').sort_index()
        
    tuples = [(setting, c) for c in df.columns]
    columns = pd.MultiIndex.from_tuples(tuples)
    
    df.columns = columns
    
    return df

# %%
input_dir = '../data/model_expressions/'
vocab_dir = '../data/model_vocab/'

dfs = []

# RefCOCO / RefCOCO+

for dset in ['refcoco', 'refcoco+']:
    for split in ['testA', 'testB']:
        df = compute_scores(dset, split, input_dir, vocab_dir)
        dfs.append(df)
#        display(df)

# RefCOCOg
        
dset = 'refcocog'
split = 'test'

df = compute_scores(dset, split, input_dir, vocab_dir)
dfs.append(df)
#display(df)

combined_df = pd.concat(dfs, axis=1)
# Out:
# testA
# testB
# testA+
# testB+
# testg

# %%
combined_df = combined_df * 100

# %%
idx = combined_df.index.get_level_values(0)
combined_df.style.format('{:.1f}').background_gradient(subset=pd.IndexSlice[idx[:-1], :])
# Out:
# <style  type="text/css" >
# #T_3925a_row0_col0,#T_3925a_row0_col3{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_3925a_row0_col1{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_3925a_row0_col2,#T_3925a_row5_col11{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_3925a_row0_col4,#T_3925a_row0_col6,#T_3925a_row0_col7,#T_3925a_row0_col10,#T_3925a_row0_col12,#T_3925a_row0_col13,#T_3925a_row1_col0,#T_3925a_row1_col1,#T_3925a_row1_col2,#T_3925a_row1_col3,#T_3925a_row1_col5,#T_3925a_row1_col8,#T_3925a_row1_col9,#T_3925a_row1_col11,#T_3925a_row1_col14{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_3925a_row0_col5,#T_3925a_row1_col6{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_3925a_row0_col8{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_3925a_row0_col9{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_3925a_row0_col11,#T_3925a_row5_col8{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_3925a_row0_col14{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_3925a_row1_col4{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_3925a_row1_col7{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_3925a_row1_col10,#T_3925a_row5_col12{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_3925a_row1_col12{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_3925a_row1_col13{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_3925a_row2_col0{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_3925a_row2_col1{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_3925a_row2_col2{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_3925a_row2_col3{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_3925a_row2_col4{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_3925a_row2_col5{
#             background-color:  #eee9f3;
#             color:  #000000;
#         }#T_3925a_row2_col6{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_3925a_row2_col7,#T_3925a_row7_col8{
#             background-color:  #a2bcda;
#             color:  #000000;
#         }#T_3925a_row2_col8{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_3925a_row2_col9{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_3925a_row2_col10,#T_3925a_row3_col4{
#             background-color:  #78abd0;
#             color:  #000000;
#         }#T_3925a_row2_col11{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_3925a_row2_col12,#T_3925a_row2_col13,#T_3925a_row6_col9,#T_3925a_row7_col0{
#             background-color:  #ced0e6;
#             color:  #000000;
#         }#T_3925a_row2_col14{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_3925a_row3_col0{
#             background-color:  #83afd3;
#             color:  #000000;
#         }#T_3925a_row3_col1{
#             background-color:  #549cc7;
#             color:  #000000;
#         }#T_3925a_row3_col2{
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }#T_3925a_row3_col3{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_3925a_row3_col5,#T_3925a_row6_col4{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_3925a_row3_col6{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_3925a_row3_col7{
#             background-color:  #197db7;
#             color:  #000000;
#         }#T_3925a_row3_col8{
#             background-color:  #93b5d6;
#             color:  #000000;
#         }#T_3925a_row3_col9{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_3925a_row3_col10,#T_3925a_row7_col7{
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }#T_3925a_row3_col11{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_3925a_row3_col12,#T_3925a_row6_col7{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_3925a_row3_col13,#T_3925a_row7_col6{
#             background-color:  #65a3cb;
#             color:  #000000;
#         }#T_3925a_row3_col14{
#             background-color:  #84b0d3;
#             color:  #000000;
#         }#T_3925a_row4_col0,#T_3925a_row4_col1,#T_3925a_row4_col2,#T_3925a_row4_col3,#T_3925a_row4_col4,#T_3925a_row4_col5,#T_3925a_row4_col6,#T_3925a_row4_col7,#T_3925a_row4_col8,#T_3925a_row4_col9,#T_3925a_row4_col10,#T_3925a_row4_col11,#T_3925a_row4_col12,#T_3925a_row4_col13,#T_3925a_row4_col14{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_3925a_row5_col0,#T_3925a_row6_col0{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_3925a_row5_col1{
#             background-color:  #e0dded;
#             color:  #000000;
#         }#T_3925a_row5_col2{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_3925a_row5_col3,#T_3925a_row5_col9{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_3925a_row5_col4{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_3925a_row5_col5{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_3925a_row5_col6{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_3925a_row5_col7,#T_3925a_row5_col10{
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }#T_3925a_row5_col13,#T_3925a_row7_col5{
#             background-color:  #cccfe5;
#             color:  #000000;
#         }#T_3925a_row5_col14{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_3925a_row6_col1{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_3925a_row6_col2{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_3925a_row6_col3,#T_3925a_row6_col8{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_3925a_row6_col5{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_3925a_row6_col6{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_3925a_row6_col10{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_3925a_row6_col11{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_3925a_row6_col12{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_3925a_row6_col13{
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }#T_3925a_row6_col14{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_3925a_row7_col1{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_3925a_row7_col2{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_3925a_row7_col3{
#             background-color:  #9fbad9;
#             color:  #000000;
#         }#T_3925a_row7_col4{
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_3925a_row7_col9{
#             background-color:  #4a98c5;
#             color:  #000000;
#         }#T_3925a_row7_col10{
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }#T_3925a_row7_col11{
#             background-color:  #81aed2;
#             color:  #000000;
#         }#T_3925a_row7_col12{
#             background-color:  #7bacd1;
#             color:  #000000;
#         }#T_3925a_row7_col13{
#             background-color:  #529bc7;
#             color:  #000

# %% [raw]
# print(
#     combined_df.round(1).to_latex()
# )
